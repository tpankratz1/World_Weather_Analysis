# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 753

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | mehran
# Processing Record 3 of Set 1 | ray
# Processing Record 4 of Set 1 | ngunguru
# Processing Record 5 of Set 1 | geraldton
# Processing Record 6 of Set 1 | srednekolymsk
# Processing Record 7 of Set 1 | sena madureira
# Processing Record 8 of Set 1 | hilo
# Processing Record 9 of Set 1 | new norfolk
# Processing Record 10 of Set 1 | burkhala
# City not found. Skipping...
# Processing Record 11 of Set 1 | buraydah
# Processing Record 12 of Set 1 | sept-iles
# Processing Record 13 of Set 1 | mersing
# Processing Record 14 of Set 1 | boguchany
# Processing Record 15 of Set 1 | castro
# Processing Record 16 of Set 1 | hermanus
# Processing Record 17 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 1 | duki
# Processing Record 19 of Set 1 | pemba
# Processing Record 20 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 1 | cidreira
# Processing Record 22 of Set 1 | hasaki
# Processing Record 23 of Set 1 | antalaha
# Processing Record 24 of Set 1 | bethel
# Processing Record 25 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 26 of Set 1 | samarai
# Processing Record 27 of Set 1 | albany
# Processing Record 28 of Set 1 | vila franca do campo
# Processing Record 29 of Set 1 | marsh harbour
# Processing Record 30 of Set 1 | longhua
# Processing Record 31 of Set 1 | ushuaia
# Processing Record 32 of Set 1 | ilulissat
# Processing Record 33 of Set 1 | tiksi
# Processing Record 34 of Set 1 | sabang
# Processing Record 35 of Set 1 | kapaa
# Processing Record 36 of Set 1 | mrirt
# City not found. Skipping...
# Processing Record 37 of Set 1 | acapulco
# Processing Record 38 of Set 1 | watsa
# Processing Record 39 of Set 1 | yellowknife
# Processing Record 40 of Set 1 | isangel
# Processing Record 41 of Set 1 | port alfred
# Processing Record 42 of Set 1 | ilave
# Processing Record 43 of Set 1 | keita
# Processing Record 44 of Set 1 | ambilobe
# Processing Record 45 of Set 1 | jamestown
# Processing Record 46 of Set 1 | port elizabeth
# Processing Record 47 of Set 1 | vila velha
# Processing Record 48 of Set 1 | mataura
# Processing Record 49 of Set 1 | pekalongan
# Processing Record 50 of Set 1 | souillac
# Processing Record 1 of Set 2 | ravar
# Processing Record 2 of Set 2 | poum
# Processing Record 3 of Set 2 | sibiti
# Processing Record 4 of Set 2 | conde
# Processing Record 5 of Set 2 | punta arenas
# Processing Record 6 of Set 2 | tuatapere
# Processing Record 7 of Set 2 | bredasdorp
# Processing Record 8 of Set 2 | tongsa
# City not found. Skipping...
# Processing Record 9 of Set 2 | karasjok
# Processing Record 10 of Set 2 | lebu
# Processing Record 11 of Set 2 | vaini
# Processing Record 12 of Set 2 | sidi ali
# Processing Record 13 of Set 2 | imphal
# Processing Record 14 of Set 2 | busselton
# Processing Record 15 of Set 2 | tongliao
# Processing Record 16 of Set 2 | avarua
# Processing Record 17 of Set 2 | kudahuvadhoo
# Processing Record 18 of Set 2 | dekernes
# Processing Record 19 of Set 2 | kodiak
# Processing Record 20 of Set 2 | atuona
# Processing Record 21 of Set 2 | nemuro
# Processing Record 22 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 23 of Set 2 | mar del plata
# Processing Record 24 of Set 2 | sitka
# Processing Record 25 of Set 2 | hannibal
# Processing Record 26 of Set 2 | la ronge
# Processing Record 27 of Set 2 | hobart
# Processing Record 28 of Set 2 | khatanga
# Processing Record 29 of Set 2 | kruisfontein
# Processing Record 30 of Set 2 | rawson
# Processing Record 31 of Set 2 | shingu
# Processing Record 32 of Set 2 | koboko
# Processing Record 33 of Set 2 | ribeira grande
# Processing Record 34 of Set 2 | sabya
# Processing Record 35 of Set 2 | constitucion
# Processing Record 36 of Set 2 | ponta do sol
# Processing Record 37 of Set 2 | ancud
# Processing Record 38 of Set 2 | nova granada
# Processing Record 39 of Set 2 | mahebourg
# Processing Record 40 of Set 2 | zhitikara
# City not found. Skipping...
# Processing Record 41 of Set 2 | alice springs
# Processing Record 42 of Set 2 | saint george
# Processing Record 43 of Set 2 | general roca
# Processing Record 44 of Set 2 | ati
# Processing Record 45 of Set 2 | cape town
# Processing Record 46 of Set 2 | leningradskiy
# Processing Record 47 of Set 2 | chokurdakh
# Processing Record 48 of Set 2 | yamaga
# Processing Record 49 of Set 2 | dikson
# Processing Record 50 of Set 2 | tiquicheo
# Processing Record 1 of Set 3 | lamu
# Processing Record 2 of Set 3 | arraial do cabo
# Processing Record 3 of Set 3 | bluff
# Processing Record 4 of Set 3 | qaanaaq
# Processing Record 5 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 6 of Set 3 | barrow
# Processing Record 7 of Set 3 | sokoni
# Processing Record 8 of Set 3 | sao miguel do iguacu
# Processing Record 9 of Set 3 | kavaratti
# Processing Record 10 of Set 3 | sao borja
# Processing Record 11 of Set 3 | evanston
# Processing Record 12 of Set 3 | saint-georges
# Processing Record 13 of Set 3 | guerrero negro
# Processing Record 14 of Set 3 | georgetown
# Processing Record 15 of Set 3 | lincoln
# Processing Record 16 of Set 3 | verkhoyansk
# Processing Record 17 of Set 3 | olafsvik
# Processing Record 18 of Set 3 | itoman
# Processing Record 19 of Set 3 | upington
# Processing Record 20 of Set 3 | skagastrond
# City not found. Skipping...
# Processing Record 21 of Set 3 | sobolevo
# Processing Record 22 of Set 3 | airai
# Processing Record 23 of Set 3 | saskylakh
# Processing Record 24 of Set 3 | thompson
# Processing Record 25 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 26 of Set 3 | vardo
# Processing Record 27 of Set 3 | lavrentiya
# Processing Record 28 of Set 3 | jaboatao
# Processing Record 29 of Set 3 | saint-louis
# Processing Record 30 of Set 3 | grand gaube
# Processing Record 31 of Set 3 | bengkulu
# Processing Record 32 of Set 3 | whitehorse
# Processing Record 33 of Set 3 | upernavik
# Processing Record 34 of Set 3 | ostrovnoy
# Processing Record 35 of Set 3 | itupiranga
# Processing Record 36 of Set 3 | dingle
# Processing Record 37 of Set 3 | salalah
# Processing Record 38 of Set 3 | atar
# Processing Record 39 of Set 3 | sola
# Processing Record 40 of Set 3 | sao jose da coroa grande
# Processing Record 41 of Set 3 | chichli
# Processing Record 42 of Set 3 | yar-sale
# Processing Record 43 of Set 3 | ibra
# Processing Record 44 of Set 3 | garden city
# Processing Record 45 of Set 3 | tuktoyaktuk
# Processing Record 46 of Set 3 | kysyl-syr
# Processing Record 47 of Set 3 | muisne
# Processing Record 48 of Set 3 | monze
# Processing Record 49 of Set 3 | elko
# Processing Record 50 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 1 of Set 4 | petropavl
# Processing Record 2 of Set 4 | north bend
# Processing Record 3 of Set 4 | esperance
# Processing Record 4 of Set 4 | peniche
# Processing Record 5 of Set 4 | san patricio
# Processing Record 6 of Set 4 | najran
# Processing Record 7 of Set 4 | henties bay
# Processing Record 8 of Set 4 | dubbo
# Processing Record 9 of Set 4 | muros
# Processing Record 10 of Set 4 | hithadhoo
# Processing Record 11 of Set 4 | chuy
# Processing Record 12 of Set 4 | east london
# Processing Record 13 of Set 4 | poronaysk
# Processing Record 14 of Set 4 | rocha
# Processing Record 15 of Set 4 | carnarvon
# Processing Record 16 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 17 of Set 4 | tubruq
# City not found. Skipping...
# Processing Record 18 of Set 4 | pangkalanbuun
# Processing Record 19 of Set 4 | macas
# Processing Record 20 of Set 4 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 21 of Set 4 | banda aceh
# Processing Record 22 of Set 4 | gadsden
# Processing Record 23 of Set 4 | san marcos
# Processing Record 24 of Set 4 | mormugao
# Processing Record 25 of Set 4 | vung tau
# Processing Record 26 of Set 4 | kieta
# Processing Record 27 of Set 4 | galiwinku
# City not found. Skipping...
# Processing Record 28 of Set 4 | zambezi
# Processing Record 29 of Set 4 | victoria
# Processing Record 30 of Set 4 | kloulklubed
# Processing Record 31 of Set 4 | tzucacab
# Processing Record 32 of Set 4 | charters towers
# Processing Record 33 of Set 4 | alexandria
# Processing Record 34 of Set 4 | natal
# Processing Record 35 of Set 4 | raahe
# Processing Record 36 of Set 4 | nikolskoye
# Processing Record 37 of Set 4 | karratha
# Processing Record 38 of Set 4 | ovalle
# Processing Record 39 of Set 4 | matara
# Processing Record 40 of Set 4 | sorong
# Processing Record 41 of Set 4 | norman wells
# Processing Record 42 of Set 4 | sao filipe
# Processing Record 43 of Set 4 | portland
# Processing Record 44 of Set 4 | yerbogachen
# Processing Record 45 of Set 4 | villa rica
# Processing Record 46 of Set 4 | baykit
# Processing Record 47 of Set 4 | tessalit
# Processing Record 48 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 49 of Set 4 | saint-pierre
# Processing Record 50 of Set 4 | tasiilaq
# Processing Record 1 of Set 5 | palmer
# Processing Record 2 of Set 5 | akdepe
# Processing Record 3 of Set 5 | el alto
# Processing Record 4 of Set 5 | puerto ayora
# Processing Record 5 of Set 5 | fortuna
# Processing Record 6 of Set 5 | komsomolskiy
# Processing Record 7 of Set 5 | saint-philippe
# Processing Record 8 of Set 5 | simbahan
# Processing Record 9 of Set 5 | lata
# Processing Record 10 of Set 5 | araouane
# Processing Record 11 of Set 5 | kandrian
# Processing Record 12 of Set 5 | comodoro rivadavia
# Processing Record 13 of Set 5 | los llanos de aridane
# Processing Record 14 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 15 of Set 5 | alenquer
# Processing Record 16 of Set 5 | kaitangata
# Processing Record 17 of Set 5 | makakilo city
# Processing Record 18 of Set 5 | grand centre
# City not found. Skipping...
# Processing Record 19 of Set 5 | mount isa
# Processing Record 20 of Set 5 | cap malheureux
# Processing Record 21 of Set 5 | kodinar
# Processing Record 22 of Set 5 | auki
# Processing Record 23 of Set 5 | changji
# Processing Record 24 of Set 5 | saint-francois
# Processing Record 25 of Set 5 | yaan
# Processing Record 26 of Set 5 | adrar
# Processing Record 27 of Set 5 | noshiro
# Processing Record 28 of Set 5 | machico
# Processing Record 29 of Set 5 | college
# Processing Record 30 of Set 5 | balabac
# Processing Record 31 of Set 5 | ewo
# Processing Record 32 of Set 5 | wajima
# Processing Record 33 of Set 5 | oudtshoorn
# Processing Record 34 of Set 5 | malindi
# Processing Record 35 of Set 5 | mogadishu
# Processing Record 36 of Set 5 | fevralsk
# City not found. Skipping...
# Processing Record 37 of Set 5 | lasa
# Processing Record 38 of Set 5 | nantucket
# Processing Record 39 of Set 5 | toora-khem
# Processing Record 40 of Set 5 | chitaga
# Processing Record 41 of Set 5 | cabo san lucas
# Processing Record 42 of Set 5 | houston
# Processing Record 43 of Set 5 | boli
# Processing Record 44 of Set 5 | cape elizabeth
# City not found. Skipping...
# Processing Record 45 of Set 5 | rio claro
# Processing Record 46 of Set 5 | smirnykh
# Processing Record 47 of Set 5 | laukaa
# Processing Record 48 of Set 5 | hihya
# Processing Record 49 of Set 5 | vestmannaeyjar
# Processing Record 50 of Set 5 | iralaya
# Processing Record 1 of Set 6 | pryazha
# Processing Record 2 of Set 6 | bathsheba
# Processing Record 3 of Set 6 | ust-nera
# Processing Record 4 of Set 6 | narsaq
# Processing Record 5 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 6 of Set 6 | joshimath
# Processing Record 7 of Set 6 | alta floresta
# Processing Record 8 of Set 6 | fukuma
# Processing Record 9 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 6 | verkhnevilyuysk
# Processing Record 11 of Set 6 | jalu
# Processing Record 12 of Set 6 | itarare
# Processing Record 13 of Set 6 | inderborskiy
# City not found. Skipping...
# Processing Record 14 of Set 6 | juxtlahuaca
# Processing Record 15 of Set 6 | kavieng
# Processing Record 16 of Set 6 | payo
# Processing Record 17 of Set 6 | okha
# Processing Record 18 of Set 6 | atherton
# Processing Record 19 of Set 6 | qaqortoq
# Processing Record 20 of Set 6 | amazar
# Processing Record 21 of Set 6 | butaritari
# Processing Record 22 of Set 6 | nisia floresta
# Processing Record 23 of Set 6 | bandarbeyla
# Processing Record 24 of Set 6 | belyy yar
# Processing Record 25 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 26 of Set 6 | san pedro
# Processing Record 27 of Set 6 | rabo de peixe
# Processing Record 28 of Set 6 | guanica
# Processing Record 29 of Set 6 | raudeberg
# Processing Record 30 of Set 6 | baiyin
# Processing Record 31 of Set 6 | mezen
# Processing Record 32 of Set 6 | kendari
# Processing Record 33 of Set 6 | hendaye
# Processing Record 34 of Set 6 | deputatskiy
# Processing Record 35 of Set 6 | sibolga
# Processing Record 36 of Set 6 | sterling
# Processing Record 37 of Set 6 | marzuq
# Processing Record 38 of Set 6 | chumikan
# Processing Record 39 of Set 6 | pimentel
# Processing Record 40 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 41 of Set 6 | cairns
# Processing Record 42 of Set 6 | qasigiannguit
# Processing Record 43 of Set 6 | ondorhaan
# City not found. Skipping...
# Processing Record 44 of Set 6 | iquique
# Processing Record 45 of Set 6 | fredonia
# Processing Record 46 of Set 6 | iskateley
# Processing Record 47 of Set 6 | sananduva
# Processing Record 48 of Set 6 | sao felix do xingu
# Processing Record 49 of Set 6 | pangnirtung
# Processing Record 50 of Set 6 | longyearbyen
# Processing Record 1 of Set 7 | tunduru
# City not found. Skipping...
# Processing Record 2 of Set 7 | bereda
# Processing Record 3 of Set 7 | tazovskiy
# Processing Record 4 of Set 7 | tombouctou
# Processing Record 5 of Set 7 | safford
# Processing Record 6 of Set 7 | shawville
# Processing Record 7 of Set 7 | barcelos
# Processing Record 8 of Set 7 | namibe
# Processing Record 9 of Set 7 | lulea
# Processing Record 10 of Set 7 | aykhal
# Processing Record 11 of Set 7 | goure
# Processing Record 12 of Set 7 | porto novo
# Processing Record 13 of Set 7 | te anau
# Processing Record 14 of Set 7 | mandalgovi
# Processing Record 15 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 16 of Set 7 | aste
# Processing Record 17 of Set 7 | champerico
# Processing Record 18 of Set 7 | teshie
# Processing Record 19 of Set 7 | matamoros
# Processing Record 20 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 21 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 22 of Set 7 | severo-kurilsk
# Processing Record 23 of Set 7 | port lincoln
# Processing Record 24 of Set 7 | rawannawi
# City not found. Skipping...
# Processing Record 25 of Set 7 | wellington
# Processing Record 26 of Set 7 | muroto
# Processing Record 27 of Set 7 | urucurituba
# Processing Record 28 of Set 7 | lima
# Processing Record 29 of Set 7 | barwaha
# City not found. Skipping...
# Processing Record 30 of Set 7 | waihi
# Processing Record 31 of Set 7 | dukat
# Processing Record 32 of Set 7 | uige
# Processing Record 33 of Set 7 | pevek
# Processing Record 34 of Set 7 | benguela
# Processing Record 35 of Set 7 | boysun
# Processing Record 36 of Set 7 | eureka
# Processing Record 37 of Set 7 | lorengau
# Processing Record 38 of Set 7 | north platte
# Processing Record 39 of Set 7 | paamiut
# Processing Record 40 of Set 7 | yalutorovsk
# Processing Record 41 of Set 7 | iqaluit
# Processing Record 42 of Set 7 | morant bay
# Processing Record 43 of Set 7 | itigi
# Processing Record 44 of Set 7 | aklavik
# Processing Record 45 of Set 7 | libenge
# Processing Record 46 of Set 7 | karkaralinsk
# City not found. Skipping...
# Processing Record 47 of Set 7 | asau
# Processing Record 48 of Set 7 | wajir
# Processing Record 49 of Set 7 | katherine
# Processing Record 50 of Set 7 | vikhorevka
# Processing Record 1 of Set 8 | zlobin
# Processing Record 2 of Set 8 | dicabisagan
# Processing Record 3 of Set 8 | tucumcari
# Processing Record 4 of Set 8 | lagoa
# Processing Record 5 of Set 8 | havoysund
# Processing Record 6 of Set 8 | bosobolo
# Processing Record 7 of Set 8 | half moon bay
# Processing Record 8 of Set 8 | conakry
# Processing Record 9 of Set 8 | faanui
# Processing Record 10 of Set 8 | brae
# Processing Record 11 of Set 8 | skovde
# City not found. Skipping...
# Processing Record 12 of Set 8 | saldanha
# Processing Record 13 of Set 8 | nelson bay
# Processing Record 14 of Set 8 | pisco
# Processing Record 15 of Set 8 | faya
# Processing Record 16 of Set 8 | kautokeino
# Processing Record 17 of Set 8 | gbarnga
# Processing Record 18 of Set 8 | muncar
# Processing Record 19 of Set 8 | orimattila
# Processing Record 20 of Set 8 | ucluelet
# Processing Record 21 of Set 8 | lalsot
# Processing Record 22 of Set 8 | hualmay
# Processing Record 23 of Set 8 | husavik
# Processing Record 24 of Set 8 | huarmey
# Processing Record 25 of Set 8 | haines junction
# Processing Record 26 of Set 8 | japura
# Processing Record 27 of Set 8 | luderitz
# Processing Record 28 of Set 8 | moron
# Processing Record 29 of Set 8 | yagodnoye
# Processing Record 30 of Set 8 | concepcion
# Processing Record 31 of Set 8 | batemans bay
# Processing Record 32 of Set 8 | svetlyy
# Processing Record 33 of Set 8 | kargasok
# Processing Record 34 of Set 8 | tepatitlan
# City not found. Skipping...
# Processing Record 35 of Set 8 | abu dhabi
# Processing Record 36 of Set 8 | timra
# Processing Record 37 of Set 8 | codrington
# Processing Record 38 of Set 8 | aragats
# Processing Record 39 of Set 8 | souris
# Processing Record 40 of Set 8 | tiznit
# Processing Record 41 of Set 8 | zhuozhou
# City not found. Skipping...
# Processing Record 42 of Set 8 | beloha
# Processing Record 43 of Set 8 | cabra
# Processing Record 44 of Set 8 | ambon
# Processing Record 45 of Set 8 | azangaro
# Processing Record 46 of Set 8 | beian
# Processing Record 47 of Set 8 | talnakh
# Processing Record 48 of Set 8 | homer
# Processing Record 49 of Set 8 | abeche
# Processing Record 50 of Set 8 | kahului
# Processing Record 1 of Set 9 | san cristobal
# Processing Record 2 of Set 9 | southbridge
# Processing Record 3 of Set 9 | belcista
# Processing Record 4 of Set 9 | san quintin
# Processing Record 5 of Set 9 | tacoronte
# Processing Record 6 of Set 9 | cherskiy
# Processing Record 7 of Set 9 | kununurra
# Processing Record 8 of Set 9 | minas
# Processing Record 9 of Set 9 | noumea
# Processing Record 10 of Set 9 | trincomalee
# Processing Record 11 of Set 9 | vila do maio
# Processing Record 12 of Set 9 | jasper
# Processing Record 13 of Set 9 | loandjili
# Processing Record 14 of Set 9 | boali
# Processing Record 15 of Set 9 | saint-augustin
# Processing Record 16 of Set 9 | inhambane
# Processing Record 17 of Set 9 | gizo
# Processing Record 18 of Set 9 | gumdag
# Processing Record 19 of Set 9 | pahrump
# Processing Record 20 of Set 9 | cumana
# Processing Record 21 of Set 9 | seymchan
# Processing Record 22 of Set 9 | kisangani
# Processing Record 23 of Set 9 | bonfim
# Processing Record 24 of Set 9 | mehamn
# Processing Record 25 of Set 9 | wattegama
# Processing Record 26 of Set 9 | batagay-alyta
# Processing Record 27 of Set 9 | zempoala
# Processing Record 28 of Set 9 | jambi
# Processing Record 29 of Set 9 | katesh
# Processing Record 30 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 31 of Set 9 | ordu
# Processing Record 32 of Set 9 | sumkino
# Processing Record 33 of Set 9 | yamada
# Processing Record 34 of Set 9 | karaton
# Processing Record 35 of Set 9 | chimoio
# Processing Record 36 of Set 9 | hofn
# Processing Record 37 of Set 9 | nortelandia
# Processing Record 38 of Set 9 | margate
# Processing Record 39 of Set 9 | sao joao da barra
# Processing Record 40 of Set 9 | martapura
# Processing Record 41 of Set 9 | clyde river
# Processing Record 42 of Set 9 | omsk
# Processing Record 43 of Set 9 | sainte-suzanne
# Processing Record 44 of Set 9 | tezu
# Processing Record 45 of Set 9 | brigantine
# Processing Record 46 of Set 9 | oktyabrskiy
# Processing Record 47 of Set 9 | bulgan
# Processing Record 48 of Set 9 | brits
# Processing Record 49 of Set 9 | springbok
# Processing Record 50 of Set 9 | klaksvik
# Processing Record 1 of Set 10 | avera
# Processing Record 2 of Set 10 | la grande
# Processing Record 3 of Set 10 | phan rang
# City not found. Skipping...
# Processing Record 4 of Set 10 | havelock
# Processing Record 5 of Set 10 | hambantota
# Processing Record 6 of Set 10 | dryden
# Processing Record 7 of Set 10 | westport
# Processing Record 8 of Set 10 | birjand
# Processing Record 9 of Set 10 | kennett
# Processing Record 10 of Set 10 | fairbanks
# Processing Record 11 of Set 10 | omagh
# Processing Record 12 of Set 10 | dalby
# Processing Record 13 of Set 10 | kyabram
# Processing Record 14 of Set 10 | vao
# Processing Record 15 of Set 10 | altagracia de orituco
# Processing Record 16 of Set 10 | vyartsilya
# Processing Record 17 of Set 10 | torbay
# Processing Record 18 of Set 10 | kyren
# Processing Record 19 of Set 10 | dauriya
# Processing Record 20 of Set 10 | ciudad bolivar
# Processing Record 21 of Set 10 | bambous virieux
# Processing Record 22 of Set 10 | solovetskiy
# City not found. Skipping...
# Processing Record 23 of Set 10 | havre-saint-pierre
# Processing Record 24 of Set 10 | nizhnevartovsk
# Processing Record 25 of Set 10 | thunder bay
# Processing Record 26 of Set 10 | chenzhou
# Processing Record 27 of Set 10 | luena
# Processing Record 28 of Set 10 | kaitong
# Processing Record 29 of Set 10 | yeppoon
# Processing Record 30 of Set 10 | panorama
# Processing Record 31 of Set 10 | vanimo
# Processing Record 32 of Set 10 | honningsvag
# Processing Record 33 of Set 10 | turukhansk
# Processing Record 34 of Set 10 | tura
# Processing Record 35 of Set 10 | praia
# Processing Record 36 of Set 10 | lokoja
# Processing Record 37 of Set 10 | ballina
# Processing Record 38 of Set 10 | hay river
# Processing Record 39 of Set 10 | vrangel
# Processing Record 40 of Set 10 | zhanatas
# City not found. Skipping...
# Processing Record 41 of Set 10 | camacha
# Processing Record 42 of Set 10 | daxian
# City not found. Skipping...
# Processing Record 43 of Set 10 | piranshahr
# Processing Record 44 of Set 10 | thinadhoo
# Processing Record 45 of Set 10 | mareeba
# Processing Record 46 of Set 10 | amapa
# Processing Record 47 of Set 10 | basay
# Processing Record 48 of Set 10 | ijaki
# City not found. Skipping...
# Processing Record 49 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 10 | finschhafen
# Processing Record 1 of Set 11 | guozhen
# Processing Record 2 of Set 11 | pontianak
# Processing Record 3 of Set 11 | luganville
# Processing Record 4 of Set 11 | waingapu
# Processing Record 5 of Set 11 | beyneu
# Processing Record 6 of Set 11 | maniitsoq
# Processing Record 7 of Set 11 | gat
# Processing Record 8 of Set 11 | carutapera
# Processing Record 9 of Set 11 | hammerfest
# Processing Record 10 of Set 11 | aran
# Processing Record 11 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 12 of Set 11 | seoul
# Processing Record 13 of Set 11 | kundiawa
# Processing Record 14 of Set 11 | lompoc
# Processing Record 15 of Set 11 | byron bay
# Processing Record 16 of Set 11 | puerto del rosario
# Processing Record 17 of Set 11 | palana
# Processing Record 18 of Set 11 | kibala
# Processing Record 19 of Set 11 | rolla
# Processing Record 20 of Set 11 | mirnyy
# Processing Record 21 of Set 11 | akonolinga
# Processing Record 22 of Set 11 | gao
# Processing Record 23 of Set 11 | kharp
# Processing Record 24 of Set 11 | kalemie
# Processing Record 25 of Set 11 | marinette
# Processing Record 26 of Set 11 | blagoyevo
# Processing Record 27 of Set 11 | goderich
# Processing Record 28 of Set 11 | nanortalik
# Processing Record 29 of Set 11 | port hedland
# Processing Record 30 of Set 11 | uspenka
# Processing Record 31 of Set 11 | berzovia
# Processing Record 32 of Set 11 | zaraza
# Processing Record 33 of Set 11 | masallatah
# Processing Record 34 of Set 11 | yakshur-bodya
# City not found. Skipping...
# Processing Record 35 of Set 11 | nur
# Processing Record 36 of Set 11 | ahipara
# Processing Record 37 of Set 11 | san marco in lamis
# Processing Record 38 of Set 11 | quatre cocos
# Processing Record 39 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 40 of Set 11 | black river
# Processing Record 41 of Set 11 | vyatskiye polyany
# Processing Record 42 of Set 11 | alcantara
# Processing Record 43 of Set 11 | san lawrenz
# Processing Record 44 of Set 11 | port-cartier
# Processing Record 45 of Set 11 | linhares
# Processing Record 46 of Set 11 | nouadhibou
# Processing Record 47 of Set 11 | shihezi
# Processing Record 48 of Set 11 | berlevag
# Processing Record 49 of Set 11 | somerset
# Processing Record 50 of Set 11 | safwah
# City not found. Skipping...
# Processing Record 1 of Set 12 | bonaventure
# Processing Record 2 of Set 12 | hun
# Processing Record 3 of Set 12 | rizhao
# Processing Record 4 of Set 12 | khormuj
# City not found. Skipping...
# Processing Record 5 of Set 12 | lucapa
# Processing Record 6 of Set 12 | yabelo
# Processing Record 7 of Set 12 | beringovskiy
# Processing Record 8 of Set 12 | hof
# Processing Record 9 of Set 12 | vilyuysk
# Processing Record 10 of Set 12 | korla
# Processing Record 11 of Set 12 | svecha
# Processing Record 12 of Set 12 | high level
# Processing Record 13 of Set 12 | sereflikochisar
# Processing Record 14 of Set 12 | katangli
# Processing Record 15 of Set 12 | jieshi
# Processing Record 16 of Set 12 | kita
# Processing Record 17 of Set 12 | eldama ravine
# Processing Record 18 of Set 12 | sorokino
# Processing Record 19 of Set 12 | oxford
# Processing Record 20 of Set 12 | gilgit
# Processing Record 21 of Set 12 | chalus
# Processing Record 22 of Set 12 | cayenne
# Processing Record 23 of Set 12 | okhotsk
# Processing Record 24 of Set 12 | san andres
# Processing Record 25 of Set 12 | kerman
# Processing Record 26 of Set 12 | wassenaar
# Processing Record 27 of Set 12 | burhaniye
# Processing Record 28 of Set 12 | tobol
# Processing Record 29 of Set 12 | san pedro de ycuamandiyu
# Processing Record 30 of Set 12 | salas
# Processing Record 31 of Set 12 | bambey
# Processing Record 32 of Set 12 | mabaruma
# Processing Record 33 of Set 12 | jaciara
# Processing Record 34 of Set 12 | mitsamiouli
# Processing Record 35 of Set 12 | killybegs
# Processing Record 36 of Set 12 | okakarara
# Processing Record 37 of Set 12 | parintins
# Processing Record 38 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 39 of Set 12 | almenara
# Processing Record 40 of Set 12 | cassilandia
# Processing Record 41 of Set 12 | ugoofaaru
# Processing Record 42 of Set 12 | santa maria del oro
# Processing Record 43 of Set 12 | port hardy
# Processing Record 44 of Set 12 | lumby
# Processing Record 45 of Set 12 | bremerton
# Processing Record 46 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 47 of Set 12 | bari sadri
# Processing Record 48 of Set 12 | almazar
# Processing Record 49 of Set 12 | mogoytuy
# Processing Record 50 of Set 12 | garowe
# Processing Record 1 of Set 13 | nieuw amsterdam
# Processing Record 2 of Set 13 | sirari
# Processing Record 3 of Set 13 | rio cuarto
# Processing Record 4 of Set 13 | dzhusaly
# City not found. Skipping...
# Processing Record 5 of Set 13 | edinburg
# Processing Record 6 of Set 13 | provideniya
# Processing Record 7 of Set 13 | ewa beach
# Processing Record 8 of Set 13 | naryan-mar
# Processing Record 9 of Set 13 | severomuysk
# Processing Record 10 of Set 13 | lensk
# Processing Record 11 of Set 13 | katsuura
# Processing Record 12 of Set 13 | kachikau
# City not found. Skipping...
# Processing Record 13 of Set 13 | weihe
# Processing Record 14 of Set 13 | sinnamary
# Processing Record 15 of Set 13 | corn island
# Processing Record 16 of Set 13 | eirunepe
# Processing Record 17 of Set 13 | bonavista
# Processing Record 18 of Set 13 | pathein
# Processing Record 19 of Set 13 | tahta
# Processing Record 20 of Set 13 | rincon
# Processing Record 21 of Set 13 | rawatbhata
# Processing Record 22 of Set 13 | irbit
# Processing Record 23 of Set 13 | zyryanka
# Processing Record 24 of Set 13 | yerofey pavlovich
# Processing Record 25 of Set 13 | frontignan
# Processing Record 26 of Set 13 | kabwe
# Processing Record 27 of Set 13 | cockburn town
# Processing Record 28 of Set 13 | crab hill
# City not found. Skipping...
# Processing Record 29 of Set 13 | panjab
# Processing Record 30 of Set 13 | antofagasta
# Processing Record 31 of Set 13 | almaznyy
# Processing Record 32 of Set 13 | platanos
# Processing Record 33 of Set 13 | taoudenni
# Processing Record 34 of Set 13 | dekar
# Processing Record 35 of Set 13 | burnie
# Processing Record 36 of Set 13 | hella
# Processing Record 37 of Set 13 | manokwari
# Processing Record 38 of Set 13 | dzhebariki-khaya
# Processing Record 39 of Set 13 | puga
# Processing Record 40 of Set 13 | ritchie
# Processing Record 41 of Set 13 | naze
# Processing Record 42 of Set 13 | saint-leu
# Processing Record 43 of Set 13 | dumas
# Processing Record 44 of Set 13 | karlskrona
# Processing Record 45 of Set 13 | udachnyy
# Processing Record 46 of Set 13 | kamenka
# Processing Record 47 of Set 13 | sheridan
# Processing Record 48 of Set 13 | nchelenge
# Processing Record 49 of Set 13 | bowen
# Processing Record 50 of Set 13 | raghunathpur
# Processing Record 1 of Set 14 | nome
# Processing Record 2 of Set 14 | kilindoni
# Processing Record 3 of Set 14 | pozo colorado
# Processing Record 4 of Set 14 | kosh-agach
# Processing Record 5 of Set 14 | mulanje
# Processing Record 6 of Set 14 | dakar
# Processing Record 7 of Set 14 | maragogi
# Processing Record 8 of Set 14 | chagda
# City not found. Skipping...
# Processing Record 9 of Set 14 | kuminskiy
# Processing Record 10 of Set 14 | tabas
# Processing Record 11 of Set 14 | gari
# Processing Record 12 of Set 14 | urumqi
# Processing Record 13 of Set 14 | lady frere
# Processing Record 14 of Set 14 | pitimbu
# Processing Record 15 of Set 14 | bagan
# Processing Record 16 of Set 14 | lethem
# Processing Record 17 of Set 14 | trelew
# Processing Record 18 of Set 14 | goundi
# Processing Record 19 of Set 14 | takoradi
# Processing Record 20 of Set 14 | afmadu
# City not found. Skipping...
# Processing Record 21 of Set 14 | hobyo
# Processing Record 22 of Set 14 | arlit
# Processing Record 23 of Set 14 | murwillumbah
# Processing Record 24 of Set 14 | kulykiv
# Processing Record 25 of Set 14 | medea
# Processing Record 26 of Set 14 | tres arroyos
# Processing Record 27 of Set 14 | barabinsk
# Processing Record 28 of Set 14 | magnitogorsk
# Processing Record 29 of Set 14 | sakaiminato
# Processing Record 30 of Set 14 | innisfail
# Processing Record 31 of Set 14 | chisec
# Processing Record 32 of Set 14 | doha
# Processing Record 33 of Set 14 | dalbandin
# Processing Record 34 of Set 14 | sur
# Processing Record 35 of Set 14 | sinop
# Processing Record 36 of Set 14 | webuye
# Processing Record 37 of Set 14 | solnechnyy
# Processing Record 38 of Set 14 | pampa
# Processing Record 39 of Set 14 | maputo
# Processing Record 40 of Set 14 | bacuit
# City not found. Skipping...
# Processing Record 41 of Set 14 | loubomo
# Processing Record 42 of Set 14 | abu samrah
# Processing Record 43 of Set 14 | zhuhai
# Processing Record 44 of Set 14 | gondar
# Processing Record 45 of Set 14 | elk plain
# Processing Record 46 of Set 14 | bubaque
# Processing Record 47 of Set 14 | klyuchi
# Processing Record 48 of Set 14 | san borja
# Processing Record 49 of Set 14 | jibuti
# Processing Record 50 of Set 14 | bestobe
# Processing Record 1 of Set 15 | hunza
# City not found. Skipping...
# Processing Record 2 of Set 15 | mahajanga
# Processing Record 3 of Set 15 | varhaug
# Processing Record 4 of Set 15 | basco
# Processing Record 5 of Set 15 | saint-andre-avellin
# Processing Record 6 of Set 15 | zhanaozen
# Processing Record 7 of Set 15 | zandvoort
# Processing Record 8 of Set 15 | balakliya
# Processing Record 9 of Set 15 | talara
# Processing Record 10 of Set 15 | nokaneng
# Processing Record 11 of Set 15 | tautira
# Processing Record 12 of Set 15 | calabozo
# Processing Record 13 of Set 15 | moussoro
# Processing Record 14 of Set 15 | sataua
# City not found. Skipping...
# Processing Record 15 of Set 15 | olinda
# Processing Record 16 of Set 15 | dunedin
# Processing Record 17 of Set 15 | mineiros
# Processing Record 18 of Set 15 | eenhana
# Processing Record 19 of Set 15 | moree
# Processing Record 20 of Set 15 | port hawkesbury
# Processing Record 21 of Set 15 | susurluk
# Processing Record 22 of Set 15 | yangcun
# Processing Record 23 of Set 15 | san michele al tagliamento
# Processing Record 24 of Set 15 | bitung
# Processing Record 25 of Set 15 | mocambique
# City not found. Skipping...
# Processing Record 26 of Set 15 | kathmandu
# Processing Record 27 of Set 15 | grindavik
# Processing Record 28 of Set 15 | marawi
# Processing Record 29 of Set 15 | motala
# Processing Record 30 of Set 15 | male
# Processing Record 31 of Set 15 | bloemhof
# Processing Record 32 of Set 15 | ciamis
# Processing Record 33 of Set 15 | timizart
# Processing Record 34 of Set 15 | ouranopolis
# City not found. Skipping...
# Processing Record 35 of Set 15 | tawkar
# City not found. Skipping...
# Processing Record 36 of Set 15 | coahuayana
# Processing Record 37 of Set 15 | kadykchan
# City not found. Skipping...
# Processing Record 38 of Set 15 | padang
# Processing Record 39 of Set 15 | qiryat motzkin
# Processing Record 40 of Set 15 | lichinga
# Processing Record 41 of Set 15 | guajara-mirim
# City not found. Skipping...
# Processing Record 42 of Set 15 | amudat
# Processing Record 43 of Set 15 | alamosa
# Processing Record 44 of Set 15 | tabialan
# City not found. Skipping...
# Processing Record 45 of Set 15 | leopoldina
# Processing Record 46 of Set 15 | suzhou
# Processing Record 47 of Set 15 | gamba
# Processing Record 48 of Set 15 | yarada
# Processing Record 49 of Set 15 | ponta delgada
# Processing Record 50 of Set 15 | necochea
# Processing Record 1 of Set 16 | ibb
# Processing Record 2 of Set 16 | monte alegre
# Processing Record 3 of Set 16 | aitape
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Rikitea -23.1203 -134.9692     76.86        70         100
# 1          Mehran  33.1222   46.1646     42.28        45           9
# 2             Ray  23.6833   85.0500     52.57        46           3
# 3        Ngunguru -35.6167  174.5000     72.16        70          96
# 4       Geraldton -28.7667  114.6000     72.01        83         100
# 5   Srednekolymsk  67.4500  153.6833    -29.49       100         100
# 6  Sena Madureira  -9.0656  -68.6569     76.03        91          71
# 7            Hilo  19.7297 -155.0900     77.11        61          20
# 8     New Norfolk -42.7826  147.0587     73.65        48           3
# 9        Buraydah  26.3260   43.9750     55.85        41          86
#
#    Wind Speed Country Current Description
# 0        5.06      PF     overcast clouds
# 1        7.58      IR           clear sky
# 2        2.01      IN           clear sky
# 3       16.28      NZ     overcast clouds
# 4        9.22      AU     overcast clouds
# 5        2.42      RU     overcast clouds
# 6        2.28      BR       broken clouds
# 7        8.05      US          few clouds
# 8        1.01      AU           clear sky
# 9       11.59      SA     overcast clouds

# %%
len(city_data)
# Out:
# 688

# %%
new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Rikitea      PF -23.1203 -134.9692     76.86        70         100
# 1          Mehran      IR  33.1222   46.1646     42.28        45           9
# 2             Ray      IN  23.6833   85.0500     52.57        46           3
# 3        Ngunguru      NZ -35.6167  174.5000     72.16        70          96
# 4       Geraldton      AU -28.7667  114.6000     72.01        83         100
# 5   Srednekolymsk      RU  67.4500  153.6833    -29.49       100         100
# 6  Sena Madureira      BR  -9.0656  -68.6569     76.03        91          71
# 7            Hilo      US  19.7297 -155.0900     77.11        61          20
# 8     New Norfolk      AU -42.7826  147.0587     73.65        48           3
# 9        Buraydah      SA  26.3260   43.9750     55.85        41          86
#
#    Wind Speed Current Description
# 0        5.06     overcast clouds
# 1        7.58           clear sky
# 2        2.01           clear sky
# 3       16.28     overcast clouds
# 4        9.22     overcast clouds
# 5        2.42     overcast clouds
# 6        2.28       broken clouds
# 7        8.05          few clouds
# 8        1.01           clear sky
# 9       11.59     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
